# %%
import pandas as pd

# Load dataset
df = pd.read_csv('tox21.csv')

# Initial inspection
print("Initial Info:")
df.info()

print("\nMissing values before cleaning:")
print(df.isnull().sum())

# Drop unnecessary columns
df = df.drop(['mol_id', 'smiles'], axis=1)

# Handle missing values using median
df.fillna(df.median(), inplace=True)

# Final verification
print("\nMissing values after cleaning:")
print(df.isnull().sum())

print("\nFinal Info:")
df.info()

print("\nDataset Summary:")
print(df.describe())

print("\nShape:", df.shape)
# Out:
# Initial Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7831 entries, 0 to 7830
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NR-AR          7265 non-null   float64
#  1   NR-AR-LBD      6758 non-null   float64
#  2   NR-AhR         6549 non-null   float64
#  3   NR-Aromatase   5821 non-null   float64
#  4   NR-ER          6193 non-null   float64
#  5   NR-ER-LBD      6955 non-null   float64
#  6   NR-PPAR-gamma  6450 non-null   float64
#  7   SR-ARE         5832 non-null   float64
#  8   SR-ATAD5       7072 non-null   float64
#  9   SR-HSE         6467 non-null   float64
#  10  SR-MMP         5810 non-null   float64
#  11  SR-p53         6774 non-null   float64
#  12  mol_id         7831 non-null   object
#  13  smiles         7831 non-null   object
# dtypes: float64(12), object(2)
# memory usage: 856.6+ KB
#
# Missing values before cleaning:
# NR-AR             566
# NR-AR-LBD        1073
# NR-AhR           1282
# NR-Aromatase     2010
# NR-ER            1638
# NR-ER-LBD         876
# NR-PPAR-gamma    1381
# SR-ARE           1999
# SR-ATAD5          759
# SR-HSE           1364
# SR-MMP           2021
# SR-p53           1057
# mol_id              0
# smiles              0
# dtype: int64
#
# Missing values after cleaning:
# NR-AR            0
# NR-AR-LBD        0
# NR-AhR           0
# NR-Aromatase     0
# NR-ER            0
# NR-ER-LBD        0
# NR-PPAR-gamma    0
# SR-ARE           0
# SR-ATAD5         0
# SR-HSE           0
# SR-MMP           0
# SR-p53           0
# dtype: int64
#
# Final Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7831 entries, 0 to 7830
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NR-AR          7831 non-null   float64
#  1   NR-AR-LBD      7831 non-null   float64
#  2   NR-AhR         7831 non-null   float64
#  3   NR-Aromatase   7831 non-null   float64
#  4   NR-ER          7831 non-null   float64
#  5   NR-ER-LBD      7831 non-null   float64
#  6   NR-PPAR-gamma  7831 non-null   float64
#  7   SR-ARE         7831 non-null   float64
#  8   SR-ATAD5       7831 non-null   float64
#  9   SR-HSE         7831 non-null   float64
#  10  SR-MMP         7831 non-null   float64
#  11  SR-p53         7831 non-null   float64
# dtypes: float64(12)
# memory usage: 734.3 KB
#
# Dataset Summary:
#              NR-AR    NR-AR-LBD       NR-AhR  NR-Aromatase        NR-ER  \
# count  7831.000000  7831.000000  7831.000000   7831.000000  7831.000000
# mean      0.039459     0.030264     0.098072      0.038309     0.101264
# std       0.194696     0.171325     0.297431      0.191954     0.301698
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000     0.000000      0.000000     0.000000
# 50%       0.000000     0.000000     0.000000      0.000000     0.000000
# 75%       0.000000     0.000000     0.000000      0.000000     0.000000
# max       1.000000     1.000000     1.000000      1.000000     1.000000
#
#          NR-ER-LBD  NR-PPAR-gamma       SR-ARE     SR-ATAD5       SR-HSE  \
# count  7831.000000    7831.000000  7831.000000  7831.000000  7831.000000
# mean      0.044694       0.023752     0.120291     0.033712     0.047504
# std       0.206645       0.152285     0.325322     0.180499     0.212727
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000       0.000000     0.000000     0.000000     0.000000
# max       1.000000       1.000000     1.000000     1.000000     1.000000
#
#             SR-MMP       SR-p53
# count  7831.000000  7831.000000
# mean      0.117226     0.054016
# std       0.321710     0.226064
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       1.000000     1.000000
#
# Shape: (7831, 12)
